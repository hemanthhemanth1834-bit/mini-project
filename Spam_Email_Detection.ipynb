# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthhemanth1834-bit/mini-project/blob/main/Spam_Email_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas scikit-learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

data = {
    'text': [
        "Win a free iPhone now",
        "Meeting scheduled at 10 AM",
        "Congratulations, you won lottery",
        "Project deadline is tomorrow",
        "Claim your free prize money"
    ],
    'label': ['spam', 'ham', 'spam', 'ham', 'spam']
}

df = pd.DataFrame(data)

X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['label'], test_size=0.3, random_state=42
)

vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

model = MultinomialNB()
model.fit(X_train_vec, y_train)

y_pred = model.predict(X_test_vec)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

new_email = ["Meeting is tomorrow at 2 PM"]
new_email_vec = vectorizer.transform(new_email)
print("\nPrediction:", model.predict(new_email_vec)[0])
# Out:
# Accuracy: 0.5
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          ham       0.00      0.00      0.00         1
#         spam       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#
# Prediction: ham

# %%
data = {
    'text': [
        "Win a free iPhone now",
        "Meeting scheduled at 10 AM",
        "Congratulations, you won lottery",
        "Project deadline is tomorrow",
        "Claim your free prize money",
        "Your Amazon order has shipped",
        "Click here to claim reward",
        "Team meeting at 3 PM",
        "Limited time offer",
        "Lunch with friends tomorrow",
        "You have won cash prize",
        "Complete your assignment",
        "Free recharge available",
        "Your bank account statement",
        "Exclusive discount for you",
        "Happy Birthday!",
        "Urgent! Verify your account",
        "Let's attend today's class",
        "Earn money from home",
        "See you tomorrow"
    ],
    'label': [
        "spam","ham","spam","ham","spam",
        "ham","spam","ham","spam","ham",
        "spam","ham","spam","ham","spam",
        "ham","spam","ham","spam","ham"
    ]
}

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning

warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.00      0.00      0.00         1
#         spam       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
